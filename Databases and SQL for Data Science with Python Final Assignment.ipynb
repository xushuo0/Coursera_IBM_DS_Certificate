# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# <h1 align=center><font size = 5>Assignment: Notebook for Peer Assignment</font></h1>

# %% [markdown]
# # Introduction
#
# Using this Python notebook you will:
#
# 1.  Understand three Chicago datasets
# 2.  Load the three datasets into three tables in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Understand the datasets
#
# To complete the assignment problems in this notebook you will be using three datasets that are available on the city of Chicago's Data Portal:
#
# 1.  <a href="https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2">Socioeconomic Indicators in Chicago</a>
# 2.  <a href="https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t">Chicago Public Schools</a>
# 3.  <a href="https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2">Chicago Crime Data</a>
#
# ### 1. Socioeconomic Indicators in Chicago
#
# This dataset contains a selection of six socioeconomic indicators of public health significance and a “hardship index,” for each Chicago community area, for the years 2008 – 2012.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2](https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 2. Chicago Public Schools
#
# This dataset shows all school level performance data used to create CPS School Report Cards for the 2011-2012 school year. This dataset is provided by the city of Chicago's Data Portal.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 3. Chicago Crime Data
#
# This dataset reflects reported incidents of crime (with the exception of murders where data exists for each victim) that occurred in the City of Chicago from 2001 to present, minus the most recent seven days.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to have these three tables populated with a subset of the whole datasets.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the links below to download and save the datasets (.CSV files):
#
# -   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv" target="_blank">Chicago Census Data</a>
#
# -   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv" target="_blank">Chicago Public Schools</a>
#
# -   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv" target="_blank">Chicago Crime Data</a>
#
# **NOTE:** Ensure you have downloaded the datasets using the links above instead of directly from the Chicago Data Portal. The versions linked here are subsets of the original datasets and have some of the column names modified to be more database friendly which will make it easier to complete this assignment.

# %% [markdown]
# ### Store the datasets in database tables
#
# To analyze the data using SQL, it first needs to be stored in the database.
#
# While it is easier to read the dataset into a Pandas dataframe and then PERSIST it into the database as we saw in Week 3 Lab 3, it results in mapping to default datatypes which may not be optimal for SQL querying. For example a long textual field may map to a CLOB instead of a VARCHAR.
#
# Therefore, **it is highly recommended to manually load the table using the database console LOAD tool, as indicated in Week 2 Lab 1 Part II**. The only difference with that lab is that in Step 5 of the instructions you will need to click on create "(+) New Table" and specify the name of the table you want to create and then click "Next".
#
# <img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/images/LoadingData.png">
#
# ##### Now open the Db2 console, open the LOAD tool, Select / Drag the .CSV file for the first dataset, Next create a New Table, and then follow the steps on-screen instructions to load the data. Name the new tables as follows:
#
# 1.  **CENSUS_DATA**
# 2.  **CHICAGO_PUBLIC_SCHOOLS**
# 3.  **CHICAGO_CRIME_DATA**

# %%
! pip install ipython-sql
! pip install ibm-db-sa
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.4.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: six in c:\users\xushu\anaconda3\lib\site-packages (from ipython-sql) (1.15.0)
# Collecting sqlparse
#   Downloading sqlparse-0.4.1-py3-none-any.whl (42 kB)
# Collecting prettytable<1
#   Downloading prettytable-0.7.2.tar.bz2 (21 kB)
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\users\xushu\anaconda3\lib\site-packages (from ipython-sql) (1.3.20)
# Requirement already satisfied: ipython>=1.0 in c:\users\xushu\anaconda3\lib\site-packages (from ipython-sql) (7.19.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\xushu\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\xushu\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in c:\users\xushu\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.17.1)
# Requirement already satisfied: pygments in c:\users\xushu\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (2.7.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\xushu\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\xushu\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (3.0.8)
# Requirement already satisfied: decorator in c:\users\xushu\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\xushu\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (50.3.1.post20201107)
# Requirement already satisfied: backcall in c:\users\xushu\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\xushu\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (5.0.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\xushu\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\xushu\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (setup.py): started
#   Building wheel for prettytable (setup.py): finished with status 'done'
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13705 sha256=e2ec5fe017a3ec79af348655516e69a4ec3cf4d299a46ec1d1efbf36d99dc8d6
#   Stored in directory: c:\users\xushu\appdata\local\pip\cache\wheels\46\60\6c\bb25d05df22906786206e901e9354bb3061061191116768bee
# Successfully built prettytable
# Installing collected packages: sqlparse, prettytable, ipython-sql
# Successfully installed ipython-sql-0.4.0 prettytable-0.7.2 sqlparse-0.4.1
# Collecting ibm-db-sa
#   Downloading ibm_db_sa-0.3.6.tar.gz (29 kB)
# Requirement already satisfied: sqlalchemy>=0.7.3 in c:\users\xushu\anaconda3\lib\site-packages (from ibm-db-sa) (1.3.20)
# Collecting ibm_db>=2.0.0
#   Downloading ibm_db-3.0.4.tar.gz (796 kB)
# Building wheels for collected packages: ibm-db-sa, ibm-db
#   Building wheel for ibm-db-sa (setup.py): started
#   Building wheel for ibm-db-sa (setup.py): finished with status 'done'
#   Created wheel for ibm-db-sa: filename=ibm_db_sa-0.3.6-py3-none-any.whl size=28864 sha256=33024317d5a7b96f150bd42855a2fabdc2ed444a034fba0f2dde80357e92b2db
#   Stored in directory: c:\users\xushu\appdata\local\pip\cache\wheels\0a\14\3e\68351001754b4456f3f7273753e9684736ca85eba8046f36b9
#   Building wheel for ibm-db (setup.py): started
#   Building wheel for ibm-db (setup.py): finished with status 'done'
#   Created wheel for ibm-db: filename=ibm_db-3.0.4-py3-none-any.whl size=27449754 sha256=12e7056ab230f41b0392e813063c1ee512313cc211e892f28397df69b5762348
#   Stored in directory: c:\users\xushu\appdata\local\pip\cache\wheels\d3\b4\35\a36838dd28cd2a15e4df56e859803d0a0387069e0f951a013e
# Successfully built ibm-db-sa ibm-db
# Installing collected packages: ibm-db, ibm-db-sa
# Successfully installed ibm-db-3.0.4 ibm-db-sa-0.3.6

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %load_ext sql

# %% [markdown]
# In the next cell enter your db2 connection string. Recall you created Service Credentials for your Db2 instance in first lab in Week 3. From the **uri** field of your Db2 service credentials copy everything after db2:// (except the double quote at the end) and paste it in the cell below after ibm_db_sa://
#
# <img src ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_edX/images/URI.jpg">

# %%
# Remember the connection string is of the format:
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name
# Enter the connection string for your Db2 on Cloud database instance below
# %sql ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Out:
# DB2/LINUXX8664

# %% [markdown]
# #### Check the columns of a table.

# %%
# %sql select * from SYSCAT.COLUMNS where TABNAME = 'CHICAGO_PUBLIC_SCHOOLS';
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'School_ID', 0, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'NAME_OF_SCHOOL', 1, 'SYSIBM  ', 'VARCHAR', 65, 0, 'OCTETS', 65, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Elementary, Middle, or High School', 2, 'SYSIBM  ', 'VARCHAR', 2, 0, 'OCTETS', 2, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00', '\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Street_Address', 3, 'SYSIBM  ', 'VARCHAR', 29, 0, 'OCTETS', 29, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'City', 4, 'SYSIBM  ', 'VARCHAR', 7, 0, 'OCTETS', 7, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'State', 5, 'SYSIBM  ', 'VARCHAR', 2, 0, 'OCTETS', 2, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00', '\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ZIP_Code', 6, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Phone_Number', 7, 'SYSIBM  ', 'VARCHAR', 14, 0, 'OCTETS', 14, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Link', 8, 'SYSIBM  ', 'VARCHAR', 78, 0, 'OCTETS', 78, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Network_Manager', 9, 'SYSIBM  ', 'VARCHAR', 40, 0, 'OCTETS', 40, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Collaborative_Name', 10, 'SYSIBM  ', 'VARCHAR', 34, 0, 'OCTETS', 34, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Adequate_Yearly_Progress_Made_', 11, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00', '\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Track_Schedule', 12, 'SYSIBM  ', 'VARCHAR', 12, 0, 'OCTETS', 12, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'CPS_Performance_Policy_Status', 13, 'SYSIBM  ', 'VARCHAR', 16, 0, 'OCTETS', 16, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'CPS_Performance_Policy_Level', 14, 'SYSIBM  ', 'VARCHAR', 15, 0, 'OCTETS', 15, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'HEALTHY_SCHOOL_CERTIFIED', 15, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00', '\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Safety_Icon', 16, 'SYSIBM  ', 'VARCHAR', 11, 0, 'OCTETS', 11, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'SAFETY_SCORE', 17, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00', '\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Family_Involvement_Icon', 18, 'SYSIBM  ', 'VARCHAR', 11, 0, 'OCTETS', 11, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Family_Involvement_Score', 19, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00', '\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Environment_Icon', 20, 'SYSIBM  ', 'VARCHAR', 11, 0, 'OCTETS', 11, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Environment_Score', 21, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00', '\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Instruction_Icon', 22, 'SYSIBM  ', 'VARCHAR', 11, 0, 'OCTETS', 11, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Instruction_Score', 23, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00', '\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Leaders_Icon', 24, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Leaders_Score', 25, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00', '\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Teachers_Icon', 26, 'SYSIBM  ', 'VARCHAR', 11, 0, 'OCTETS', 11, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Teachers_Score', 27, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00', '\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Parent_Engagement_Icon', 28, 'SYSIBM  ', 'VARCHAR', 7, 0, 'OCTETS', 7, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Parent_Engagement_Score', 29, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00', '\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Parent_Environment_Icon', 30, 'SYSIBM  ', 'VARCHAR', 7, 0, 'OCTETS', 7, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Parent_Environment_Score', 31, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00', '\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'AVERAGE_STUDENT_ATTENDANCE', 32, 'SYSIBM  ', 'VARCHAR', 6, 0, 'OCTETS', 6, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Rate_of_Misconducts__per_100_students_', 33, 'SYSIBM  ', 'DECIMAL', 5, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00\x00', '\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Average_Teacher_Attendance', 34, 'SYSIBM  ', 'VARCHAR', 6, 0, 'OCTETS', 6, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Individualized_Education_Program_Compliance_Rate', 35, 'SYSIBM  ', 'VARCHAR', 7, 0, 'OCTETS', 7, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Pk_2_Literacy__', 36, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Pk_2_Math__', 37, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr3_5_Grade_Level_Math__', 38, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr3_5_Grade_Level_Read__', 39, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr3_5_Keep_Pace_Read__', 40, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr3_5_Keep_Pace_Math__', 41, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr6_8_Grade_Level_Math__', 42, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr6_8_Grade_Level_Read__', 43, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr6_8_Keep_Pace_Math_', 44, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr6_8_Keep_Pace_Read__', 45, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr_8_Explore_Math__', 46, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr_8_Explore_Read__', 47, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ISAT_Exceeding_Math__', 48, 'SYSIBM  ', 'DECIMAL', 5, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00\x00', '\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ISAT_Exceeding_Reading__', 49, 'SYSIBM  ', 'DECIMAL', 5, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00\x00', '\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ISAT_Value_Add_Math', 50, 'SYSIBM  ', 'DECIMAL', 3, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00', '\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ISAT_Value_Add_Read', 51, 'SYSIBM  ', 'DECIMAL', 3, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00', '\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ISAT_Value_Add_Color_Math', 52, 'SYSIBM  ', 'VARCHAR', 6, 0, 'OCTETS', 6, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ISAT_Value_Add_Color_Read', 53, 'SYSIBM  ', 'VARCHAR', 6, 0, 'OCTETS', 6, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Students_Taking__Algebra__', 54, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Students_Passing__Algebra__', 55, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', '9th Grade EXPLORE (2009)', 56, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', '9th Grade EXPLORE (2010)', 57, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', '10th Grade PLAN (2009)', 58, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', '10th Grade PLAN (2010)', 59, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Net_Change_EXPLORE_and_PLAN', 60, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00', '\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', '11th Grade Average ACT (2011)', 61, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Net_Change_PLAN_and_ACT', 62, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00', '\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'College_Eligibility__', 63, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Graduation_Rate__', 64, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'College_Enrollment_Rate__', 65, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'COLLEGE_ENROLLMENT', 66, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00', '\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'General_Services_Route', 67, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00', '\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Freshman_on_Track_Rate__', 68, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'X_COORDINATE', 69, 'SYSIBM  ', 'DECIMAL', 13, 3, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Y_COORDINATE', 70, 'SYSIBM  ', 'DECIMAL', 13, 3, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Latitude', 71, 'SYSIBM  ', 'DECIMAL', 18, 8, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Longitude', 72, 'SYSIBM  ', 'DECIMAL', 18, 8, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'COMMUNITY_AREA_NUMBER', 73, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00', '\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'COMMUNITY_AREA_NAME', 74, 'SYSIBM  ', 'VARCHAR', 22, 0, 'OCTETS', 22, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Ward', 75, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00', '\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Police_District', 76, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00', '\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Location', 77, 'SYSIBM  ', 'VARCHAR', 27, 0, 'OCTETS', 27, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None)]

# %% [markdown]
# ## Problems
#
# Now write and execute SQL queries to solve assignment problems
#
# ### Problem 1
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %%sql
# Select Count(*) From Chicago_Crime_Data
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('533'),)]

# %% [markdown]
# ### Problem 2
#
# ##### List community areas with per capita income less than 11000.

# %%
# %%sql
# Select Community_Area_Name From Census_Data
# Where Per_Capita_Income < 11000
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('West Garfield Park',),
#  ('South Lawndale',),
#  ('Fuller Park',),
#  ('Riverdale',)]

# %% [markdown]
# ### Problem 3
#
# ##### List all case numbers for crimes  involving minors?

# %%
# %%sql
# Select Case_Number From Chicago_Crime_Data
# Where Description Like '%MINOR%'
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('HL266884',), ('HK238408',)]

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?

# %%
# %%sql
# Select * From Chicago_Crime_Data
# Where Primary_Type = 'KIDNAPPING'
# AND DESCRIPTION Like '%CHILD%'
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(5276766, 'HN144152', datetime.date(2007, 1, 26), '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 'FALSE', 'FALSE', 1533, 15, 29, 25, '20', 1143050, 1897546, 2007, Decimal('41.87490841'), Decimal('-87.75024931'), '(41.874908413, -87.750249307)')]

# %% [markdown]
# ### Problem 5
#
# ##### What kinds of crimes were recorded at schools?

# %%
# %%sql
# Select Distinct Primary_Type From Chicago_Crime_DATA
# Where Location_Description Like '%SCHOOL%'
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('ASSAULT',),
#  ('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('CRIMINAL TRESPASS',),
#  ('NARCOTICS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %% [markdown]
# ### Problem 6
#
# ##### List the average safety score for all types of schools.

# %%
# %%sql
# Select ("Elementary, Middle, or High School") as School_Type, AVG(SAFETY_SCORE) as AVG_SAFETY_SCORE From CHICAGO_PUBLIC_SCHOOLS
# Group By ("Elementary, Middle, or High School")
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('ES', Decimal('49.520383')),
#  ('HS', Decimal('49.623529')),
#  ('MS', Decimal('48.000000'))]

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %%sql
# Select community_area_name, percent_households_below_poverty From census_data
# Order By PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC
# Limit 5
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Riverdale', Decimal('56.5')),
#  ('Fuller Park', Decimal('51.2')),
#  ('Englewood', Decimal('46.6')),
#  ('North Lawndale', Decimal('43.1')),
#  ('East Garfield Park', Decimal('42.4'))]

# %% [markdown]
# ### Problem 8
#
# ##### Which community area is most crime prone?

# %%
# %%sql
# Select Count(*) as number_of_crimes, COMMUNITY_AREA_NUMBER From CHICAGO_CRIME_DATA
# Group By COMMUNITY_AREA_NUMBER
# Order By 1 DESC
# Limit 1
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('43'), 25)]

# %%
# %%sql
# Select COMMUNITY_AREA_NAME From CENSUS_DATA
# Where COMMUNITY_AREA_NUMBER = 25;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Austin',)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Query for the 'community area number' that is most crime prone.
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %%
# %%sql
# Select COMMUNITY_AREA_NAME, HARDSHIP_INDEX From CENSUS_DATA
# Order By HARDSHIP_INDEX DESC Limit 5 OFFSET 1
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Riverdale', 98),
#  ('Fuller Park', 97),
#  ('South Lawndale', 96),
#  ('Englewood', 94),
#  ('Gage Park', 93)]

# %%
# %%sql
# With t as (Select COMMUNITY_AREA_NAME, HARDSHIP_INDEX From CENSUS_DATA Order By HARDSHIP_INDEX DESC Limit 5 OFFSET 1)
# Select COMMUNITY_AREA_NAME From t DESC Limit 1
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Riverdale',)]

# %% [markdown]
# ### Problem 10
#
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %%sql
# Select Count(*), COMMUNITY_AREA_NUMBER From CHICAGO_CRIME_DATA
# Group By COMMUNITY_AREA_NUMBER
# Order By 1 DESC Limit 1
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('43'), 25)]

# %%
# %%sql
# Select COMMUNITY_AREA_NAME From CENSUS_DATA
# Where COMMUNITY_AREA_NUMBER = 25;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Austin',)]

# %% [markdown]
# # Honors Final Project

# %% [markdown]
# ### Check columns

# %%
# %%sql
# Select * from SYSCAT.COLUMNS where TABNAME = 'CENSUS_DATA'
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('LDD04263', 'CENSUS_DATA', 'COMMUNITY_AREA_NUMBER', 0, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 78, '77', '2', 3, None, 0, 20, 10, 1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CENSUS_DATA', 'COMMUNITY_AREA_NAME', 1, 'SYSIBM  ', 'VARCHAR', 22, 0, 'OCTETS', 22, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 78, "'West Town'", "'Archer Heights'", 16, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 11, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CENSUS_DATA', 'PERCENT_OF_HOUSING_CROWDED', 2, 'SYSIBM  ', 'DECIMAL', 4, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', 56, '+015.2', '+000.8', 4, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CENSUS_DATA', 'PERCENT_HOUSEHOLDS_BELOW_POVERTY', 3, 'SYSIBM  ', 'DECIMAL', 4, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', 68, '+051.2', '+003.4', 4, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CENSUS_DATA', 'PERCENT_AGED_16__UNEMPLOYED', 4, 'SYSIBM  ', 'DECIMAL', 4, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', 67, '+034.6', '+004.9', 4, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CENSUS_DATA', 'PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 5, 'SYSIBM  ', 'DECIMAL', 4, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', 70, '+051.5', '+002.6', 4, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CENSUS_DATA', 'PERCENT_AGED_UNDER_18_OR_OVER_64', 6, 'SYSIBM  ', 'DECIMAL', 4, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', 67, '+044.9', '+017.0', 4, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CENSUS_DATA', 'PER_CAPITA_INCOME', 7, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 78, '71551', '10402', 5, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CENSUS_DATA', 'HARDSHIP_INDEX', 8, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 78, '98', '2', 3, None, 0, 20, 10, 1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None)]

# %%
# %%sql
# Select * from SYSCAT.COLUMNS where TABNAME = 'CHICAGO_PUBLIC_SCHOOLS'
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'School_ID', 0, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 566, '610543', '609674', 5, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'NAME_OF_SCHOOL', 1, 'SYSIBM  ', 'VARCHAR', 65, 0, 'OCTETS', 65, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 566, "'Woodlawn Community Elementary Sch'", "'Abraham Lincoln Elementary School'", 41, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 36, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Elementary, Middle, or High School', 2, 'SYSIBM  ', 'VARCHAR', 2, 0, 'OCTETS', 2, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 3, "'MS'", "'ES'", 7, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 2, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Street_Address', 3, 'SYSIBM  ', 'VARCHAR', 29, 0, 'OCTETS', 29, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 566, "'9912 S Avenue H'", "'10015 S Leavitt St'", 22, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 17, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'City', 4, 'SYSIBM  ', 'VARCHAR', 7, 0, 'OCTETS', 7, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 1, "'Chicago'", "'Chicago'", 12, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 7, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'State', 5, 'SYSIBM  ', 'VARCHAR', 2, 0, 'OCTETS', 2, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 1, "'IL'", "'IL'", 7, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 2, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ZIP_Code', 6, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 51, '60707', '60607', 5, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Phone_Number', 7, 'SYSIBM  ', 'VARCHAR', 14, 0, 'OCTETS', 14, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 566, "'(773) 535-9930'", "'(773) 534-0146'", 19, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 14, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Link', 8, 'SYSIBM  ', 'VARCHAR', 78, 0, 'OCTETS', 78, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 2, "''", "'http://schoolreports.cps.edu/Scho'", 83, None, 0, 20, 10, 1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 78, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Network_Manager', 9, 'SYSIBM  ', 'VARCHAR', 40, 0, 'OCTETS', 40, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 20, "'Southwest Side High School Networ'", "'Austin-North Lawndale Elementary '", 35, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 30, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Collaborative_Name', 10, 'SYSIBM  ', 'VARCHAR', 34, 0, 'OCTETS', 34, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 5, "'SOUTHWEST SIDE COLLABORATIVE'", "'NORTH-NORTHWEST SIDE COLLABORATIV'", 33, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 28, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Adequate_Yearly_Progress_Made_', 11, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 3, "'Yes'", "'NDA'", 7, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 2, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Track_Schedule', 12, 'SYSIBM  ', 'VARCHAR', 12, 0, 'OCTETS', 12, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 3, "'Track_E'", "'Non_Standard'", 13, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 8, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'CPS_Performance_Policy_Status', 13, 'SYSIBM  ', 'VARCHAR', 16, 0, 'OCTETS', 16, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 4, "'Not on Probation'", "'Not Applicable'", 18, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 13, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'CPS_Performance_Policy_Level', 14, 'SYSIBM  ', 'VARCHAR', 15, 0, 'OCTETS', 15, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 5, "'NDA'", "'Level 2'", 12, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 7, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'HEALTHY_SCHOOL_CERTIFIED', 15, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 2, "'Yes'", "'No'", 7, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 2, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Safety_Icon', 16, 'SYSIBM  ', 'VARCHAR', 11, 0, 'OCTETS', 11, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 6, "'Very Weak'", "'NDA'", 11, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 6, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'SAFETY_SCORE', 17, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 86, '99', '5', 3, None, 0, 20, 10, 53, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Family_Involvement_Icon', 18, 'SYSIBM  ', 'VARCHAR', 11, 0, 'OCTETS', 11, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 6, "'Very Weak'", "'NDA'", 10, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 5, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Family_Involvement_Score', 19, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 72, "'99'", "'17'", 7, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 2, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Environment_Icon', 20, 'SYSIBM  ', 'VARCHAR', 11, 0, 'OCTETS', 11, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 6, "'Very Weak'", "'NDA'", 11, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 6, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Environment_Score', 21, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 80, '99', '2', 3, None, 0, 20, 10, 53, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Instruction_Icon', 22, 'SYSIBM  ', 'VARCHAR', 11, 0, 'OCTETS', 11, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 6, "'Very Weak'", "'NDA'", 11, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 6, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Instruction_Score', 23, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 83, '99', '11', 3, None, 0, 20, 10, 53, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Leaders_Icon', 24, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 1, "'Weak'", "'Weak'", 9, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 4, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Leaders_Score', 25, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 79, "'99'", "'14'", 7, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 2, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Teachers_Icon', 26, 'SYSIBM  ', 'VARCHAR', 11, 0, 'OCTETS', 11, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 6, "'Very Weak'", "'NDA'", 10, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 5, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Teachers_Score', 27, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 77, "'99'", "'14'", 7, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 2, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Parent_Engagement_Icon', 28, 'SYSIBM  ', 'VARCHAR', 7, 0, 'OCTETS', 7, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 4, "'Strong'", "'NDA'", 10, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 5, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Parent_Engagement_Score', 29, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 32, "'69'", "'39'", 7, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 2, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Parent_Environment_Icon', 30, 'SYSIBM  ', 'VARCHAR', 7, 0, 'OCTETS', 7, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 4, "'Strong'", "'NDA'", 10, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 5, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Parent_Environment_Score', 31, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 33, "'70'", "'36'", 7, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 2, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'AVERAGE_STUDENT_ATTENDANCE', 32, 'SYSIBM  ', 'VARCHAR', 6, 0, 'OCTETS', 6, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 155, "'98.40%'", "'60.90%'", 11, None, 0, 20, 10, 1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 6, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Rate_of_Misconducts__per_100_students_', 33, 'SYSIBM  ', 'DECIMAL', 5, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', 288, '+0230.6', '+0000.1', 4, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Average_Teacher_Attendance', 34, 'SYSIBM  ', 'VARCHAR', 6, 0, 'OCTETS', 6, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 55, "'98.10%'", "'91.70%'", 11, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 6, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Individualized_Education_Program_Compliance_Rate', 35, 'SYSIBM  ', 'VARCHAR', 7, 0, 'OCTETS', 7, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 69, "'99.60%'", "'72.70%'", 12, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 7, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Pk_2_Literacy__', 36, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 308, "'96.3'", "'16.4'", 9, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 4, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Pk_2_Math__', 37, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 224, "'97.2'", "'10.1'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr3_5_Grade_Level_Math__', 38, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 336, "'98.6'", "'10'", 9, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 4, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr3_5_Grade_Level_Read__', 39, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 340, "'98.6'", "'10'", 9, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 4, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr3_5_Keep_Pace_Read__', 40, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 276, "'82.5'", "'28.8'", 9, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 4, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr3_5_Keep_Pace_Math__', 41, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 260, "'83.5'", "'21.7'", 9, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 4, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr6_8_Grade_Level_Math__', 42, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 296, "'96.5'", "'10.2'", 9, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 4, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr6_8_Grade_Level_Read__', 43, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 300, "'98.9'", "'100'", 9, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 4, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr6_8_Keep_Pace_Math_', 44, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 268, "'93.6'", "'24.3'", 9, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 4, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr6_8_Keep_Pace_Read__', 45, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 260, "'85.5'", "'21.4'", 9, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 4, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr_8_Explore_Math__', 46, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 208, "'9.7'", "'1.4'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Gr_8_Explore_Read__', 47, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 244, "'99'", "'1.4'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ISAT_Exceeding_Math__', 48, 'SYSIBM  ', 'DECIMAL', 5, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', 297, '+0100.0', '+0000.6', 4, None, 0, 20, 10, 90, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ISAT_Exceeding_Reading__', 49, 'SYSIBM  ', 'DECIMAL', 5, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', 261, '+0100.0', '+0000.5', 4, None, 0, 20, 10, 90, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ISAT_Value_Add_Math', 50, 'SYSIBM  ', 'DECIMAL', 3, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', 57, '+03.6', '-03.1', 3, None, 0, 20, 10, 98, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ISAT_Value_Add_Read', 51, 'SYSIBM  ', 'DECIMAL', 3, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', 60, '+04.9', '-02.8', 3, None, 0, 20, 10, 98, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ISAT_Value_Add_Color_Math', 52, 'SYSIBM  ', 'VARCHAR', 6, 0, 'OCTETS', 6, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 4, "'Red'", "'NDA'", 10, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 5, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'ISAT_Value_Add_Color_Read', 53, 'SYSIBM  ', 'VARCHAR', 6, 0, 'OCTETS', 6, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 4, "'Red'", "'NDA'", 10, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 5, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Students_Taking__Algebra__', 54, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 116, "'98.5'", "'10.5'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Students_Passing__Algebra__', 55, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 94, "'93.3'", "'11.1'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', '9th Grade EXPLORE (2009)', 56, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 45, "'22.4'", "'11.6'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', '9th Grade EXPLORE (2010)', 57, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 51, "'22.2'", "'11.2'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', '10th Grade PLAN (2009)', 58, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 45, "'24.5'", "'12.9'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', '10th Grade PLAN (2010)', 59, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 49, "'24.7'", "'12.7'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Net_Change_EXPLORE_and_PLAN', 60, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 16, "'2.3'", "'0.5'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', '11th Grade Average ACT (2011)', 61, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 53, "'28.8'", "'13.6'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Net_Change_PLAN_and_ACT', 62, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 30, "'4.3'", "'0.3'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'College_Eligibility__', 63, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 78, "'98'", "'10.6'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Graduation_Rate__', 64, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 75, "'97.6'", "'10.3'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'College_Enrollment_Rate__', 65, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 70, "'90.7'", "'32.6'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'COLLEGE_ENROLLMENT', 66, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 444, '3320', '26', 3, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'General_Services_Route', 67, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 20, '48', '30', 3, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Freshman_on_Track_Rate__', 68, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 79, "'98.1'", "'37.1'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'X_COORDINATE', 69, 'SYSIBM  ', 'DECIMAL', 13, 3, None, None, None, 'Y', 0, None, None, ' ', ' ', 504, '+0001202756.093', '+0001121355.698', 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Y_COORDINATE', 70, 'SYSIBM  ', 'DECIMAL', 13, 3, None, None, None, 'Y', 0, None, None, ' ', ' ', 560, '+0001949501.716', '+0001817244.896', 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Latitude', 71, 'SYSIBM  ', 'DECIMAL', 18, 8, None, None, None, 'Y', 0, None, None, ' ', ' ', 472, '+0000000042.01709536', '+0000000041.65376037', 11, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Longitude', 72, 'SYSIBM  ', 'DECIMAL', 18, 8, None, None, None, 'Y', 0, None, None, ' ', ' ', 566, '-0000000087.53301251', '-0000000087.82933190', 11, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'COMMUNITY_AREA_NUMBER', 73, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 77, '76', '2', 3, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'COMMUNITY_AREA_NAME', 74, 'SYSIBM  ', 'VARCHAR', 22, 0, 'OCTETS', 22, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 77, "'WEST TOWN'", "'ARCHER HEIGHTS'", 16, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 11, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Ward', 75, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 50, '49', '2', 3, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Police_District', 76, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 23, '24', '2', 3, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_PUBLIC_SCHOOLS', 'Location', 77, 'SYSIBM  ', 'VARCHAR', 27, 0, 'OCTETS', 27, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 536, "'(42.01709536, -87.67779928)'", "'(41.65376037, -87.61434156)'", 32, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 27, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None)]

# %%
# %%sql
# Select * from SYSCAT.COLUMNS where TABNAME = 'CHICAGO_CRIME_DATA'
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('LDD04263', 'CHICAGO_CRIME_DATA', 'ID', 0, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 533, '11233321', '23469', 5, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'CASE_NUMBER', 1, 'SYSIBM  ', 'VARCHAR', 8, 0, 'OCTETS', 8, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 533, "'JB155558'", "'G040244'", 13, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 8, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'DATE', 2, 'SYSIBM  ', 'DATE', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 504, "'2018-02-16'", "'2001-01-19'", 5, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'BLOCK', 3, 'SYSIBM  ', 'VARCHAR', 35, 0, 'OCTETS', 35, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 533, "'132XX S RIVERDALE AVE'", "'0000X E OHIO ST'", 23, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 18, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'IUCR', 4, 'SYSIBM  ', 'VARCHAR', 4, 0, 'OCTETS', 4, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 112, "'930'", "'041A'", 8, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 3, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'PRIMARY_TYPE', 5, 'SYSIBM  ', 'VARCHAR', 33, 0, 'OCTETS', 33, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 35, "'THEFT'", "'ASSAULT'", 15, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 10, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'DESCRIPTION', 6, 'SYSIBM  ', 'VARCHAR', 46, 0, 'OCTETS', 46, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 103, "'VEHICULAR HIJACKING'", "'AGG CRIM SEX ABUSE FAM MEMBER'", 21, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 16, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'LOCATION_DESCRIPTION', 7, 'SYSIBM  ', 'VARCHAR', 33, 0, 'OCTETS', 33, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 48, "'VEHICLE NON-COMMERCIAL'", "'ALLEY'", 16, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 11, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'ARREST', 8, 'SYSIBM  ', 'VARCHAR', 5, 0, 'OCTETS', 5, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 2, "'TRUE'", "'FALSE'", 10, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 5, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'DOMESTIC', 9, 'SYSIBM  ', 'VARCHAR', 5, 0, 'OCTETS', 5, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 2, "'TRUE'", "'FALSE'", 10, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 5, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'BEAT', 10, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 242, '2534', '112', 3, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'DISTRICT', 11, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 22, '24', '2', 3, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'WARD', 12, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 51, '50', '2', 3, None, 0, 20, 10, 43, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'COMMUNITY_AREA_NUMBER', 13, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 71, '77', '2', 3, None, 0, 20, 10, 43, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'FBICODE', 14, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 23, "'7'", "'04A'", 7, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 2, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'X_COORDINATE', 15, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 505, '1204126', '1100955', 5, None, 0, 20, 10, 4, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'Y_COORDINATE', 16, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 469, '1951001', '1817235', 5, None, 0, 20, 10, 4, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'YEAR', 17, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 18, '2017', '2002', 3, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'LATITUDE', 18, 'SYSIBM  ', 'DECIMAL', 18, 8, None, None, None, 'Y', 0, None, None, ' ', ' ', 497, '+0000000042.02117760', '+0000000041.65371054', 11, None, 0, 20, 10, 4, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'LONGITUDE', 19, 'SYSIBM  ', 'DECIMAL', 18, 8, None, None, None, 'Y', 0, None, None, ' ', ' ', 489, '-0000000087.52822298', '-0000000087.90412276', 11, None, 0, 20, 10, 4, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('LDD04263', 'CHICAGO_CRIME_DATA', 'LOCATION', 20, 'SYSIBM  ', 'VARCHAR', 29, 0, 'OCTETS', 29, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 505, "'(42.021177601, -87.67220843)'", "'(41.653710537, -87.609528714)'", 34, None, 0, 20, 10, 4, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 29, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None)]

# %% [markdown]
# ## Question 1

# %% [markdown]
# #### Write and execute a SQL query to list the school names, community names and average attendance for communities with a hardship index of 98.

# %%
# %%sql
# Select a.name_of_school, a.community_area_name, a.average_student_attendance
# From Chicago_Public_Schools as a
# Join Census_Data as b
# On a.community_area_number = b.community_area_number
# Where hardship_index = 98
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('George Washington Carver Military Academy High School', 'RIVERDALE', '91.60%'),
#  ('George Washington Carver Primary School', 'RIVERDALE', '90.90%'),
#  ('Ira F Aldridge Elementary School', 'RIVERDALE', '92.90%'),
#  ('William E B Dubois Elementary School', 'RIVERDALE', '93.30%')]

# %% [markdown]
# ## Question 2

# %% [markdown]
# #### Write and execute a SQL query to list all crimes that took place at a school. Include case number, crime type and community name.

# %%
# %%sql
# Select a.case_number, a.primary_type, b.community_area_name
# From Chicago_crime_data as a
# Left Join Census_data as b
# On a.community_area_number = b.community_area_number
# Where location_description Like '%SCHOOL%'
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('HK577020', 'NARCOTICS', 'Rogers Park'),
#  ('HL725506', 'BATTERY', 'Lincoln Square'),
#  ('HH639427', 'BATTERY', 'Austin'),
#  ('HS200939', 'CRIMINAL DAMAGE', 'Austin'),
#  ('HT315369', 'ASSAULT', 'East Garfield Park'),
#  ('HP716225', 'BATTERY', 'Douglas'),
#  ('HL353697', 'BATTERY', 'South Shore'),
#  ('HS305355', 'NARCOTICS', 'Brighton Park'),
#  ('JA460432', 'BATTERY', 'Ashburn'),
#  ('HR585012', 'CRIMINAL TRESPASS', 'Ashburn'),
#  ('HH292682', 'PUBLIC PEACE VIOLATION', None),
#  ('G635735', 'PUBLIC PEACE VIOLATION', None)]

# %% [markdown]
# ## Question 3

# %% [markdown]
# #### Write and execute a SQL statement to create a view showing the columns listed in the following table, with new column names as shown in the second column.

# %%
# %%sql
# Drop View Q2VIEW;
# Create View Q2VIEW As
# Select NAME_OF_SCHOOL as School_Name,
#        ("Safety_Icon") as Safety_Rating,
#        ("Family_Involvement_Icon") as Family_Rating,
#        ("Environment_Icon") as Environment_Rating,
#        ("Instruction_Icon") as Instruction_Rating,
#        ("Leaders_Icon") as Leaders_Rating,
#        ("Teachers_Icon") as Teachers_Rating
# FROM Chicago_public_schools;
# Select * From Q2VIEW;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# Done.
# Done.
# [('Abraham Lincoln Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('Adam Clayton Powell Paideia Community Academy Elementary School', 'Average', 'Strong', 'Strong', 'Very Strong', 'Weak', 'Strong'),
#  ('Adlai E Stevenson Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Agustin Lara Elementary Academy', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Air Force Academy High School', 'Average', 'Strong', 'Strong', 'Average', 'Weak', 'Average'),
#  ('Albany Park Multicultural Academy', 'Strong', 'Weak', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Albert G Lane Technical High School', 'Very Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Albert R Sabin Elementary Magnet School', 'Strong', 'NDA', 'Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Alcott High School for the Humanities', 'Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Alessandro Volta Elementary School', 'Average', 'Strong', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Alexander Graham Bell Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Average', 'Weak', 'Average'),
#  ('Alexander Graham Elementary School', 'Average', 'Weak', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Alexander Hamilton Elementary School', 'Strong', 'Strong', 'Strong', 'Average', 'Weak', 'Average'),
#  ('Alexander von Humboldt Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Alex Haley Elementary Academy', 'Weak', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Alfred David Kohn Elementary School', 'Very Weak', 'Weak', 'Weak', 'Very Weak', 'Weak', 'Very Weak'),
#  ('Alfred Nobel Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Alice L Barnard Computer Math & Science Center Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Al Raby High School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Ambrose Plamondon Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Amelia Earhart Options for Knowledge Elementary School', 'Very Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Ames Middle School', 'Weak', 'Very Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Amos Alonzo Stagg Elementary School', 'Weak', 'Weak', 'Weak', 'Average', 'Weak', 'Average'),
#  ('Ana Roque de Duprey Elementary School', 'Average', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Andrew Carnegie Elementary School', 'Average', 'Average', 'Weak', 'Strong', 'Weak', 'Weak'),
#  ('Andrew Jackson Elementary Language Academy', 'Very Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Anna R. Langford Community Academy', 'Weak', 'Weak', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Annie Keller Elementary Gifted Magnet School', 'Very Strong', 'Very Strong', 'Very Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('A.N. Pritzker School', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Anthony Overton Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Ariel Elementary Community Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Arna Wendell Bontemps Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Arnold Mireles Elementary Academy', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Arthur A Libby Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Arthur Dixon Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Arthur E Canty Elementary School', 'Very Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Arthur R Ashe Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Asa Philip Randolph Elementary School', 'Very Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Ashburn Community Elementary School', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Augustus H Burley Elementary School', 'Very Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Austin Business and Entrepreneurship Academy High School', 'Weak', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Austin O Sexton Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Austin Polytechnical Academy High School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Avalon Park Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Very Weak'),
#  ('Barbara Vick Early Childhood & Family Center', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Belmont-Cragin Elementary School', 'Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Benito Juarez Community Academy High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Benjamin Banneker Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Benjamin E Mays Elementary Academy', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Bernhard Moos Elementary School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Betsy Ross Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Beulah Shoesmith Elementary School', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Blair Early Childhood Center', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Strong'),
#  ('Bret Harte Elementary School', 'Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Brian Piccolo Elementary Specialty School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Brighton Park Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Bronzeville Scholastic Academy High School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Very Weak'),
#  ('Burnham Elementary Inclusive Academy', 'Strong', 'Strong', 'Very Strong', 'Very Strong', 'Weak', 'Strong'),
#  ('Burnside Elementary Scholastic Academy', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Calmeca Academy of Fine Arts and Dual Language', 'Average', 'Strong', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Carl Schurz High School', 'Average', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Carl von Linne Elementary School', 'Strong', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Carrie Jacobs Bond Elementary School', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Weak'),
#  ('Carroll-Rosenwald Specialty Elementary School', 'Weak', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Carter G Woodson South Elementary School', 'Weak', 'Weak', 'Very Weak', 'Very Weak', 'Weak', 'Average'),
#  ('Cesar E Chavez Multicultural Academic Center Elementary School', 'Average', 'Average', 'Strong', 'Average', 'Weak', 'Average'),
#  ('Charles Allen Prosser Career Academy High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Charles Evans Hughes Elementary School', 'Average', 'NDA', 'Very Strong', 'Strong', 'Weak', 'NDA'),
#  ('Charles Gates Dawes Elementary School', 'Average', 'Weak', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Charles G Hammond Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Charles H Wacker Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Charles Kozminski Elementary Community Academy', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Charles N Holden Elementary School', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Charles P Caldwell Academy of Math & Science Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Charles P Steinmetz Academic Centre High School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Charles R Darwin Elementary School', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Charles R Henderson Elementary School', 'Very Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Charles S Brownell Elementary School', 'Weak', 'Very Weak', 'Strong', 'Very Strong', 'Weak', 'Very Weak'),
#  ('Charles S Deneen Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Charles Sumner  Math & Science Community Acad Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Charles W Earle Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Chicago Academy Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Chicago Academy High School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Chicago High School for Agricultural Sciences', 'Very Strong', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('Chicago Military Academy High School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Chicago Vocational Career Academy High School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Christian Ebinger Elementary School', 'Strong', 'Strong', 'Strong', 'Average', 'Weak', 'Strong'),
#  ('Christian Fenger Academy High School', 'Weak', 'Weak', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Christopher Columbus Elementary School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Clara Barton Elementary School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Claremont Academy Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Collins Academy High School', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Columbia Explorers Elementary Academy', 'Average', 'Strong', 'Average', 'Strong', 'Weak', 'Strong'),
#  ('Countee Cullen Elementary School', 'Very Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Crispus Attucks Elementary School', 'Average', 'Strong', 'Strong', 'Average', 'Weak', 'Very Strong'),
#  ('Crown Community Academy of Fine Arts Center Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Cyrus H McCormick Elementary School', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Daniel Boone Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Daniel C Beard Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Daniel Hale Williams Prep School of Medicine', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Daniel J Corkery Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Daniel R Cameron Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Daniel S Wentworth Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Daniel Webster Elementary School', 'Average', 'Average', 'Very Strong', 'Strong', 'Weak', 'Average'),
#  ('David G Farragut Career Academy High School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('DeVry University Advantage Academy High School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Dewey Elementary Academy of Fine Arts', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('DeWitt Clinton Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Disney II Magnet School', 'NDA', 'Very Strong', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Donald Morrill Math & Science Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Douglas Taylor Elementary School', 'Weak', 'NDA', 'Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Dr Jorge Prieto Math and Science', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Dr  Martin Luther King  Jr  College Prep High School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Dumas Technology Academy', 'Very Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Dunne Technology Academy', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Durkin Park Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Dvorak Technology Academy', 'Average', 'Weak', 'Strong', 'Strong', 'Weak', 'Very Weak'),
#  ('Dyett High School', 'Weak', 'Very Weak', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('Edgar Allan Poe Elementary Classical School', 'Very Strong', 'Weak', 'Strong', 'Very Strong', 'Weak', 'Average'),
#  ('Edgebrook Elementary School', 'Very Strong', 'Very Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Edison Park Elementary School', 'Very Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Edmond Burke Elementary School', 'Very Weak', 'NDA', 'Very Weak', 'Weak', 'Weak', 'NDA'),
#  ('Edward A Bouchet Math & Science Academy Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Edward Beasley Elementary Magnet Academic Center', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Edward C Delano Elementary School', 'Weak', 'Strong', 'Strong', 'Average', 'Weak', 'Strong'),
#  ('Edward Coles Elementary Language Academy', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Edward Everett Elementary School', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Edward Jenner Elementary Academy of the Arts', 'Average', 'Weak', 'Strong', 'Average', 'Weak', 'Weak'),
#  ('Edward K Ellington Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Edward N Hurley Elementary School', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Edward Tilden Career Community Academy High School', 'Weak', 'Average', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Edward White Elementary Career Academy', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Edwin G Foreman High School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Elaine O Goodlow Elementary Magnet School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Elihu Yale Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Eli Whitney Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Elizabeth H Sutherland Elementary School', 'Very Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Elizabeth Peabody Elementary School', 'Average', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Eliza Chappell Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('Ella Flagg Young Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Ellen H Richards Career Academy High School', 'Weak', 'Weak', 'Weak', 'Very Weak', 'Weak', 'Weak'),
#  ('Ellen Mitchell Elementary School', 'Very Strong', 'Strong', 'Very Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('Emil G Hirsch Metropolitan High School', 'Very Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Emiliano Zapata Elementary Academy', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Emmett Louis Till Math and Science Academy', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Enrico Fermi Elementary School', 'Weak', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Enrico Tonti Elementary School', 'NDA', 'Average', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Eric Solorio Academy High School', 'Strong', 'Average', 'Average', 'Strong', 'Weak', 'Strong'),
#  ('Ernst Prussing Elementary School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Esmond Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Eugene Field Elementary School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Very Weak'),
#  ('Everett McKinley Dirksen Elementary School', 'Average', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Evergreen Academy Middle School', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Fairfield Elementary Academy', 'Weak', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Federico Garcia Lorca Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Very Strong'),
#  ('Wilma Rudolph Elementary Learning Center', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Ferdinand Peck Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Fernwood Elementary School', 'Weak', 'Weak', 'Very Weak', 'Average', 'Weak', 'Average'),
#  ('Florence B Price Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Florence Nightingale Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Fort Dearborn Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Foster Park Elementary School', 'Very Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Francisco I Madero Middle School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Francis M McKay Elementary School', 'Weak', 'Average', 'Weak', 'Average', 'Weak', 'Strong'),
#  ('Francis Parkman Elementary School', 'Weak', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Francis Scott Key Elementary School', 'Weak', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Francis W Parker Elementary Community Academy', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Frank I Bennett Elementary School', 'Average', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Frank L Gillespie Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Franklin Elementary Fine Arts Center', 'Very Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Frank W Gunsaulus Elementary Scholastic Academy', 'Average', 'Weak', 'Weak', 'Average', 'Weak', 'Very Weak'),
#  ('Frank W Reilly Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Franz Peter Schubert Elementary School', 'NDA', 'Weak', 'NDA', 'NDA', 'Weak', 'Weak'),
#  ('Frazier Prospective IB Magnet Elementary School', 'Strong', 'Average', 'Very Strong', 'Strong', 'Weak', 'Average'),
#  ('Frederic Chopin Elementary School', 'Very Strong', 'Very Strong', 'Very Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('Frederick A Douglass Academy High School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Frederick Funston Elementary School', 'Very Weak', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Frederick Stock Elementary School', 'NDA', 'Very Strong', 'NDA', 'NDA', 'Weak', 'Very Strong'),
#  ('Friedrich Ludwig Jahn Elementary School', 'Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Friedrich W von Steuben Metropolitan Science High School', 'Strong', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Gage Park High School', 'Very Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Galileo Math & Science Scholastic Academy Elementary School', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Garrett A Morgan Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Genevieve Melody Elementary School', 'Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('George Armstrong International Studies Elementary School', 'Average', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('George B McClellan Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('George B Swift Elementary Specialty School', 'Strong', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('George F Cassell Elementary School', 'Strong', 'Strong', 'Average', 'Weak', 'Weak', 'Strong'),
#  ('George H Corliss High School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('George Leland Elementary School', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Strong'),
#  ('George Manierre Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('George M Pullman Elementary School', 'Average', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('George Rogers Clark Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('George Washington Carver Military Academy High School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('George Washington Carver Primary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('George Washington Elementary School', 'Average', 'Strong', 'Weak', 'Average', 'Weak', 'Strong'),
#  ('George Washington High School', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('George W Curtis Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('George Westinghouse High School', 'Strong', 'Strong', 'Strong', 'Very Strong', 'Weak', 'Strong'),
#  ('George W Tilton Elementary School', 'Very Weak', 'Weak', 'Weak', 'Average', 'Weak', 'Average'),
#  ('Gerald Delgado Kanoon Elementary Magnet School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Graeme Stewart Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Granville T Woods Math & Science Academy Elementary School', 'Weak', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Greater Lawndale High School For Social Justice', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Grover Cleveland Elementary School', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Guglielmo Marconi Elementary Community Academy', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Gurdon S Hubbard High School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Gwendolyn Brooks College Preparatory Academy High School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Hannah G Solomon Elementary School', 'Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('Hanson Park Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Harold Washington Elementary School', 'Weak', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Harriet Beecher Stowe Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Harriet E Sayre Elementary Language Academy', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Hawthorne Elementary Scholastic Academy', 'Very Strong', 'Very Strong', 'Strong', 'Average', 'Weak', 'Very Strong'),
#  ('Helen M Hefferan Elementary School', 'Weak', 'Weak', 'Weak', 'Strong', 'Weak', 'Average'),
#  ('Helen Peirce International Studies Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Helge A Haugan Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Henry Clay Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Henry D Lloyd Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Henry H Nash Elementary School', 'Average', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Henry O Tanner Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Henry R Clissold Elementary School', 'Average', 'Strong', 'Weak', 'Strong', 'Weak', 'Average'),
#  ('High School of Leadership at South Shore', 'NDA', 'Weak', 'NDA', 'NDA', 'Weak', 'Weak'),
#  ('Hiram H Belding Elementary School', 'Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Hope College Preparatory High School', 'Weak', 'Average', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('Horace Greeley Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Horace Mann Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Horatio May Elementary Community Academy', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Hyde Park Academy High School', 'Weak', 'Weak', 'Weak', 'Average', 'Weak', 'Average'),
#  ('Hyman G Rickover Naval Academy High School', 'Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Ida B Wells Preparatory Elementary Academy', 'Average', 'NDA', 'Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Ignance Paderewski Elementary Learning Academy', 'Weak', 'NDA', 'Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Infinity Math Science and Technology High School', 'Average', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Inter-American Elementary Magnet School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Ira F Aldridge Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Irene C. Hernandez Middle School for the Advancement of Science', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Irma C Ruiz Elementary School', 'Average', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Irvin C Mollison Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ("Isabelle C O'Keeffe Elementary School", 'Very Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Jackie Robinson Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Jacob Beidler Elementary School', 'Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Jacqueline B Vaughn Occupational High School', 'Average', 'Strong', 'Weak', 'Weak', 'Weak', 'Strong'),
#  ('James B Farnsworth Elementary School', 'Average', 'Strong', 'Average', 'Weak', 'Weak', 'Average'),
#  ('James B McPherson Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('James E McDade Elementary Classical School', 'Very Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('James G Blaine Elementary School', 'Very Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('James Hedges Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('James Madison Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('James Monroe Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('James N Thorp Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('James Otis Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Average', 'Weak', 'Very Strong'),
#  ('James R Doolittle Jr Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('James Russell Lowell Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('James Shields Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('James Wadsworth Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('James Ward Elementary School', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('James Weldon Johnson Elementary School', 'Strong', 'Weak', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('Jane Addams Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Jane A Neil Elementary School', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Jean Baptiste Beaubien Elementary School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Jean D Lafayette Elementary School', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Strong'),
#  ('Jensen Elementary Scholastic Academy', 'Weak', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Jesse Owens Elementary Community Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Jesse Sherwood Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Johann W von Goethe Elementary School', 'Strong', 'Strong', 'Strong', 'Average', 'Weak', 'Strong'),
#  ('John A Walsh Elementary School', 'Strong', 'NDA', 'Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('John Barry Elementary School', 'Weak', 'Average', 'Strong', 'Very Strong', 'Weak', 'Average'),
#  ('John B Drake Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Very Weak'),
#  ('John B Murphy Elementary School', 'Very Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('John Calhoun North Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Very Strong'),
#  ('John C Burroughs Elementary School', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('John C Coonley Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Weak', 'Weak', 'Average'),
#  ('John C Dore Elementary School', 'Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('John Charles Haines Elementary School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('John D Shoop Math-Science Technical Academy Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('John F Eberhart Elementary School', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('John Fiske Elementary School', 'Very Weak', 'Weak', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('John F Kennedy High School', 'Average', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('John Foster Dulles Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('John Greenleaf Whittier Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('John Hancock College Preparatory High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('John Harvard Elementary School of Excellence', 'Average', 'Weak', 'Strong', 'Strong', 'Weak', 'Weak'),
#  ('John Hay Elementary Community Academy', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('John H Hamline Elementary School', 'Weak', 'Weak', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('John H Kinzie Elementary School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('John H Vanderpoel Elementary Magnet School', 'Strong', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('John J Audubon Elementary School', 'Very Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('John J Pershing Elementary Humanities Magnet', 'NDA', 'Very Strong', 'NDA', 'NDA', 'Weak', 'Strong'),
#  ('John L Marsh Elementary School', 'Strong', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('John Marshall Metropolitan High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('John M Harlan Community Academy High School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('John Milton Gregory Elementary School', 'Average', 'Average', 'Weak', 'Average', 'Weak', 'Average'),
#  ('John M Smyth Elementary School', 'Weak', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Johnnie Colemon Elementary Academy', 'Strong', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('John Palmer Elementary School', 'Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('John P Altgeld Elementary School', 'Average', 'Weak', 'Strong', 'Average', 'Weak', 'Weak'),
#  ('John Spry Elementary Community School', 'Strong', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('John T McCutcheon Elementary School', 'Average', 'Weak', 'Strong', 'Average', 'Weak', 'Average'),
#  ('John T Pirie Fine Arts & Academic Center Elementary School', 'Weak', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('John W Cook Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('John W Garvy Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('John Whistler Elementary School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Jonathan Burr Elementary School', 'Strong', 'Strong', 'Strong', 'Average', 'Weak', 'Strong'),
#  ('Jonathan Y Scammon Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Jordan Elementary Community School', 'Strong', 'Weak', 'Average', 'Average', 'Weak', 'Very Weak'),
#  ('Jose De Diego Elementary Community Academy', 'Average', 'Average', 'Weak', 'Average', 'Weak', 'Strong'),
#  ('Josefa Ortiz De Dominguez Elementary School', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Joseph Brennemann Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Joseph E Gary Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Very Weak'),
#  ('Josephine C Locke Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Joseph Jungman Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Joseph Kellman Corporate Community Elementary School', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('Joseph Lovett Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Joseph Stockton Elementary School', 'Weak', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Joseph Warren Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Joshua D Kershaw Elementary School', 'Strong', 'Strong', 'Strong', 'Average', 'Weak', 'Average'),
#  ('Josiah Pickard Elementary School', 'Average', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Joyce Kilmer Elementary School', 'NDA', 'Average', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Julia C Lathrop Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Julia Ward Howe Elementary School of Excellence', 'Strong', 'Average', 'Very Strong', 'Strong', 'Weak', 'Strong'),
#  ('Kate S Buckingham Special Education Center', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Kate S Kellogg Elementary School', 'Strong', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Kelvyn Park High School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Kenwood Academy High School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Lake View High School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Langston Hughes Elementary School', 'Weak', 'Average', 'Very Weak', 'Weak', 'Weak', 'Average'),
#  ('LaSalle Elementary Language Academy', 'Very Strong', 'Strong', 'Strong', 'Average', 'Weak', 'Average'),
#  ('LaSalle II Magnet Elementary School', 'Strong', 'Very Strong', 'Weak', 'Average', 'Weak', 'Strong'),
#  ('Laughlin Falconer Elementary School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Laura S Ward Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Lawndale Elementary Community Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Lazaro Cardenas Elementary School', 'NDA', 'Average', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Leif Ericson Elementary Scholastic Academy', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Lenart Elementary Regional Gifted Center', 'Strong', 'Average', 'Average', 'Strong', 'Weak', 'Strong'),
#  ('Leslie Lewis Elementary School', 'Weak', 'Weak', 'Weak', 'Strong', 'Weak', 'Average'),
#  ('Lincoln Park High School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('Lionel Hampton Fine & Performing Arts Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Little Village Elementary School', 'Average', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Logandale Middle School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Lorenz Brentano Math & Science Academy Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Louis A Agassiz Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Louisa May Alcott Elementary School', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Louis Armstrong Math & Science Elementary School', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Louis Nettelhorst Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Louis Pasteur Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Ludwig Van Beethoven Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ("Luke O'Toole Elementary School", 'Very Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Luther Burbank Elementary School', 'Weak', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Lyman A Budlong Elementary School', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Lyman Trumbull Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Mahalia Jackson Elementary School', 'Weak', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Mancel Talcott Elementary School', 'Strong', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Manley Career Academy High School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Manuel Perez Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Marcus Moziah Garvey Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Mariano Azuela Elementary School', 'Average', 'Very Strong', 'Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('Maria Saucedo Elementary Scholastic Academy', 'Strong', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Marie Sklodowska Curie Metropolitan High School', 'Average', 'Weak', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('Marine Military Math and Science Academy', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Mark Sheridan Elementary Math & Science Academy', 'Strong', 'Average', 'Average', 'Strong', 'Weak', 'Strong'),
#  ('Mark Skinner Elementary School', 'Very Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Mark Twain Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Marquette Elementary School', 'Very Weak', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Martha Ruggles Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Martin A Ryerson Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Marvin Camras Elementary School', 'Average', 'Average', 'Weak', 'Average', 'Weak', 'Very Strong'),
#  ('Mary E Courtenay Elementary Language Arts Center', 'Very Strong', 'NDA', 'Very Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Mary E McDowell Elementary School', 'NDA', 'Average', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Mary Gage Peterson Elementary School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Mary Lyon Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Mary Mapes Dodge Elementary Renaissance Academy', 'Average', 'Strong', 'Strong', 'Strong', 'Weak', 'Very Strong'),
#  ('Mary McLeod Bethune Elementary School', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Mason High School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Matthew A Henson Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Matthew Gallistel Elementary Language Academy', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Medgar Evers Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Melville W Fuller Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Michael Faraday Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Michael M Byrne Elementary School', 'Strong', 'Strong', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Michele Clark Academic Prep Magnet High School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Mildred I Lavizzo Elementary School', 'Very Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Milton Brunson Math & Science Specialty Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Minnie Mars Jamieson Elementary School', 'Strong', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Miriam G Canter Middle School', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Strong'),
#  ('Morgan Park High School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Morton School of Excellence', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Very Strong'),
#  ('Moses Montefiore Special Elementary School', 'Weak', 'NDA', 'Average', 'Very Weak', 'Weak', 'NDA'),
#  ('Mount Greenwood Elementary School', 'Very Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Mount Vernon Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Very Weak'),
#  ('Multicultural Academy of Scholarship', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Myra Bradwell Communications Arts & Sciences Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Nathanael Greene Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Nathan Hale Elementary School', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Nathaniel Pope Elementary School', 'Average', 'NDA', 'Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Nathan R Goldblatt Elementary School', 'Average', 'NDA', 'Very Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Nathan S Davis Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('National Teachers Elementary Academy', 'Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Neal F Simeon Career Academy High School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Near North Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('New Field Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('New Millennium High School of Health at Bowen', 'Very Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Very Weak'),
#  ('Newton Bateman Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Nicholas Senn High School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Nicholson Technology Academy', 'Average', 'Weak', 'Strong', 'Strong', 'Weak', 'Weak'),
#  ('Ninos Heroes Elementary Academic Center', 'Weak', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Norman A Bridge Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('North-Grand High School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('North River Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('Northside College Preparatory High School', 'Very Strong', 'NDA', 'Very Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Percy L Julian High School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Northside Learning Center High School', 'Very Strong', 'Very Strong', 'Very Strong', 'Weak', 'Weak', 'Very Strong'),
#  ('Northwest Middle School', 'Weak', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Norwood Park Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Weak'),
#  ('Ogden International High School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Ole A Thorp Elementary Scholastic Academy', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('Oliver S Westcott Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Oliver Wendell Holmes Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Oriole Park Elementary School', 'Very Strong', 'NDA', 'Very Strong', 'Strong', 'Weak', 'NDA'),
#  ('Orozco Fine Arts & Sciences Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Orr Academy High School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Orville T Bright Elementary School', 'Very Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Oscar DePriest Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Oscar F Mayer Elementary School', 'Strong', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Pablo Casals Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Park Manor Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Parkside Elementary Community Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Patrick Henry Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Paul Cuffe Math-Science Technology Academy Elementary School', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Very Strong'),
#  ('Paul Laurence Dunbar Career Academy High School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Paul Revere Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Paul Robeson High School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Perkins Bass Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Pershing West Middle School', 'Average', 'Average', 'Weak', 'Average', 'Weak', 'Average'),
#  ('Peter A Reinberg Elementary School', 'Strong', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Peter Cooper Elementary Dual Language Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Philip Rogers Elementary School', 'Very Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('Phillip D Armour Elementary School', 'Weak', 'NDA', 'Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Phillip Murray Elementary Language Academy', 'Strong', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Phobe Apperson Hearst Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Phoenix Military Academy High School', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Pilsen Elementary Community Academy', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Portage Park Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Pulaski International Academy Elmentary School', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Rachel Carson Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Ralph H Metcalfe Elementary Community Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Ravenswood Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Ray Graham Training Center High School', 'Very Strong', 'Very Strong', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Richard Edwards Elementary School', 'Average', 'Average', 'Weak', 'Average', 'Weak', 'Average'),
#  ('Richard Henry Lee Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Richard J Daley Elementary Academy', 'Weak', 'Average', 'Weak', 'Average', 'Weak', 'Average'),
#  ('Richard J Oglesby Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Richard T Crane Technical Preparatory High School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Richard Yates Elementary School', 'Average', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Roald Amundsen High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Robert A Black Magnet Elementary School', 'Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Robert Emmet Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Robert Fulton Elementary School', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Weak'),
#  ('Robert Healy Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Robert H Lawrence Elementary School', 'Very Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Robert L Grimes Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Robert Lindblom Math & Science Academy High School', 'Strong', 'NDA', 'Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Robert Nathaniel Dett Elementary School', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Roberto Clemente Community Academy High School', 'Average', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Rodolfo Lozano Bilingual & International Center Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Roger C Sullivan High School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Ronald Brown Elementary Community Academy', 'Weak', 'Weak', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Ronald E McNair Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Rosario Castellanos Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Roswell B Mason Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Rudyard Kipling Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Rueben Salazar Elementary Bilingual Center', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Rufus M Hitch Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Salmon P Chase Elementary School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Samuel Gompers Fine Arts Options Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Sauganash Elementary School', 'Very Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Scott Joplin Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Sharon Christa McAuliffe Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Sidney Sawyer Elementary School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Simon Guggenheim Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Sir Miles Davis Magnet Elementary Academy', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Skinner North', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Socorro Sandoval Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Songhai Elementary Learning Institute', 'Very Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('South Loop Elementary School', 'Very Strong', 'Strong', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('South Shore Fine Arts Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Southside Occupational Academy High School', 'NDA', 'Average', 'NDA', 'NDA', 'Weak', 'Strong'),
#  ('Spencer Technology Academy', 'Weak', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Spry Community Links High School', 'Strong', 'NDA', 'Very Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Stephen Decatur Classical Elementary School', 'Very Strong', 'Very Strong', 'Very Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('Stephen F Gale Elementary Community Academy', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Stephen K Hayt Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Stephen T Mather High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Stone Elementary Scholastic Academy', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Suder Montessori Magnet Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Talman Elementary School', 'Very Strong', 'Very Strong', 'Very Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('Tarkington School of Excellence Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('TEAM Englewood Community Academy High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Telpochcalli Elementary School', 'Average', 'Average', 'Very Weak', 'Weak', 'Weak', 'Strong'),
#  ('Theodore Herzl Elementary School', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Theodore Roosevelt High School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Theophilus Schmid Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Thomas A Edison Regional Gifted Center Elementary School', 'Very Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Thomas A Hendricks Elementary Community Academy', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Thomas Chalmers Specialty Elementary School', 'Weak', 'Strong', 'Weak', 'Average', 'Weak', 'Strong'),
#  ('Thomas Drummond Elementary School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Thomas Hoyne Elementary School', 'Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('Thomas J Higgins Elementary Community Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Thomas J Waters Elementary School', 'Very Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Thomas Kelly High School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Thurgood Marshall Middle School', 'Weak', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Turner-Drew Elementary Language Academy', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Uplift Community High School', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Velma F Thomas Early Childhood Center', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Victor Herbert Elementary School', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Virgil Grissom Elementary School', 'Strong', 'Strong', 'Average', 'Strong', 'Weak', 'Very Strong'),
#  ('VOISE Academy High School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Walt Disney Magnet Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Walter L Newberry Math & Science Academy Elementary School', 'Strong', 'Strong', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Walter Payton College Preparatory High School', 'Very Strong', 'NDA', 'Very Strong', 'Strong', 'Weak', 'NDA'),
#  ('Walter Q Gresham Elementary School', 'Weak', 'Average', 'Very Weak', 'Very Weak', 'Weak', 'Average'),
#  ('Walter Reed Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Walter S Christopher Elementary School', 'NDA', 'Average', 'NDA', 'NDA', 'Weak', 'Strong'),
#  ('Washington D Smyser Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Washington Irving Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Wells Community Academy High School', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Wendell E Green Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Wendell Phillips Academy High School', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Strong'),
#  ('Wendell Smith Elementary School', 'Weak', 'Weak', 'Very Weak', 'Very Weak', 'Weak', 'Weak'),
#  ('West Park Elementary Academy', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('West Pullman Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('West Ridge Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Whitney M Young Magnet High School', 'Very Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Wildwood Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Willa Cather Elementary School', 'Strong', 'Strong', 'Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('William A Hinton Elementary School', 'Very Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('William Bishop Owen Scholastic Academy Elementary School', 'Average', 'Strong', 'Weak', 'Average', 'Weak', 'Average'),
#  ('William B Ogden Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('William C Goudy Elementary School', 'Strong', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('William C Reavis Math & Science Specialty Elementary School', 'Average', 'Very Weak', 'Weak', 'Weak', 'Weak', 'Very Weak'),
#  ('William E B Dubois Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('William E Dever Elementary School', 'Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Weak'),
#  ('William F Finkl Elementary School', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('William G Hibbard Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('William H Brown Elementary School', 'Weak', 'Strong', 'Average', 'Strong', 'Weak', 'Strong'),
#  ('William H King Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('William Howard Taft High School', 'Strong', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('William H Prescott Elementary School', 'Very Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('William H Ray Elementary School', 'Strong', 'NDA', 'Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('William H Ryder Math & Science Specialty Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('William H Seward Communication Arts Academy Elementary School', 'Average', 'Average', 'Weak', 'Average', 'Weak', 'Strong'),
#  ('William J Bogan High School', 'Weak', 'NDA', 'Very Weak', 'Weak', 'Weak', 'NDA'),
#  ('William J & Charles H Mayo Elementary School', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('William J Onahan Elementary School', 'Strong', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('William Jones College Preparatory High School', 'Very Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('William K New Sullivan Elementary School', 'Weak', 'Average', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('William Penn Elementary School', 'Strong', 'NDA', 'Very Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('William P Gray Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('William P Nixon Elementary School', 'Average', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('William Rainey Harper High School', 'Weak', 'Weak', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('Williams Multiplex Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Williams Preparatory Academy Middle School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('William T Sherman Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('William W Carter Elementary School', 'Very Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Strong'),
#  ('Wolfgang A Mozart Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Woodlawn Community Elementary School', 'Strong', 'NDA', 'Very Strong', 'Strong', 'Weak', 'NDA'),
#  ('World Language Academy High School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Average')]

# %% [markdown]
# ## Question 4

# %%
# %%sql
# -- #SET TERMINATOR @
# DROP PROCEDURE UPDATE_LEADERS_SCORE
# CREATE PROCEDURE UPDATE_LEADERS_SCORE(IN in_School_ID INTEGER, IN in_Leader_Score INTEGER)
#
# LANGUAGE SQL
# MODIFIES SQL DATA
#
#
# BEGIN
#     ALTER TABLE Chicago_Public_Schools
#     ALTER  "Leaders_Icon" VARCHAR(12);
#
#     IF in_Leader_Score >= 0 AND in_Leader_Score < 20 THEN
#         UPDATE Chicago_Public_SCHOOLS
#         SET "Leaders_Icon" = 'Very weak'
#         WHERE "School_ID" = in_School_ID
#         AND "Leaders_Score" = in_Leader_Score;
#     ELSEIF in_Leader_Score < 40 THEN
#         UPDATE Chicago_Public_SCHOOLS
#         SET "Leaders_Icon" = 'Weak'
#         WHERE "School_ID" = in_School_ID
#         AND "Leaders_Score" = in_Leader_Score;
#     ELSEIF in_Leader_Score < 60 THEN
#         UPDATE Chicago_Public_SCHOOLS
#         SET "Leaders_Icon" = 'Average'
#         WHERE "School_ID" = in_School_ID
#         AND "Leaders_Score" = in_Leader_Score;
#     ELSEIF in_Leader_Score < 80 THEN
#         UPDATE Chicago_Public_SCHOOLS
#         SET "Leaders_Icon" = 'Strong'
#         WHERE "School_ID" = in_School_ID
#         AND "Leaders_Score" = in_Leader_Score;
#     ELSE
#         UPDATE Chicago_Public_SCHOOLS
#         SET "Leaders_Icon" = 'Very strong'
#         WHERE "School_ID" = in_School_ID
#         AND "Leaders_Score" = in_Leader_Score;
#     END IF;
#
#     IF in_Leader_Score >= 0 AND in_Leader_Score <=99 THEN
#         COMMIT WORK;
#     ELSE
#         ROLLBACK WORK;
#     END IF;
#
#
# END
# -- #SET TERMINATOR @
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# []

# %%
# %%sql
# Select "Leaders_Icon", "Leaders_Score" From Chicago_Public_Schools
# Where "School_ID"=609993
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Weak', '65')]

# %%
# %%sql
# Call UPDATE_LEADERS_SCORE(60993,65)
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# []

# %%
# %%sql
# Select ("Leaders_Icon"), ("Leaders_Score") From Chicago_Public_Schools
# Where ("School_ID")=609993
# ;
# Out:
#  * ibm_db_sa://ldd04263:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Weak', '65')]

# %% [markdown]
# Copyright © 2020 [cognitiveclass.ai](cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# ## Author(s)
#
# <h4> Hima Vasudevan </h4>
# <h4> Rav Ahuja </h4>
# <h4> Ramesh Sannreddy </h4>
#
# ## Contribtuor(s)
#
# <h4> Malika Singla </h4>
#
# ## Change log
#
# | Date       | Version | Changed by        | Change Description                             |
# | ---------- | ------- | ----------------- | ---------------------------------------------- |
# | 2021-01-15 | 2.2     | Rav Ahuja         | Removed problem 11 and fixed changelog         |
# | 2020-11-25 | 2.1     | Ramesh Sannareddy | Updated the problem statements, and datasets   |
# | 2020-09-05 | 2.0     | Malika Singla     | Moved lab to course repo in GitLab             |
# | 2018-07-18 | 1.0     | Rav Ahuja         | Several updates including loading instructions |
# | 2018-05-04 | 0.1     | Hima Vasudevan    | Created initial version                        |
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
